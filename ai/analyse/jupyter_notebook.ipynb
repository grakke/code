# %%
from __future__ import print_function, division
from sympy import *
import numpy as np

a, s, t, u, v, w, x, y, z = symbols("a, s, t, u, v, w, x, y, z")
k, m, n = symbols("k, m, n", integer=True)
f, g, h = symbols("f, g, h", cls=Function)
init_printing()

# %%
# !cd ~
# !pwd
# !ls ../

# %%
# %magic

# %%
from IPython.display import IFrame

IFrame('https://en.wikipedia.org/wiki/HTTPS', width=800, height=450)

# %%
from IPython.display import IFrame
IFrame('https://arxiv.org/pdf/1406.2661.pdf', width=800, height=450)

# %%
# %env

# %%
import time
% % time
for _ in range(1000):
    time.sleep(0.01)

# %%
# %who

# %%
% % html
<h1 > hello < /h1 >
<span > test < /span >

# %%
% % bash
for i in {1..5}
   do
       echo "i is $i"
    done

# %%
# !pip3 install cython fortran-magic

# %%
# %load_ext Cython

def multiply_by_2(x):
    return 2.0 * x


print(multiply_by_2(23.))

# %%
x = [
    'one',
    'two',
    'three',
    'four'
]

# %%
l = 'hello'

# %% [markdown]
# # **你好**
#
# ## MarkDown 这个世界
#
# $P(A \mid B) = \frac{P(B \mid A) , P(A)}{P(B)}$

# %%
# %time a = range(10)

# %%
% % timeit a = range(10)min(a)

# %%
# %load https://www.dataquest.io/blog/jupyter-notebook-tutorial/

# %%
# %load / Users/henry/Workspace/code/Python/syntax/data_type/list_tuple.ipynb
